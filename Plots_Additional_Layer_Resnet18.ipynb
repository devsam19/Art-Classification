# %%
import matplotlib.pyplot as plt
import pylab
from pylab import figure, axes, pie, title, show

# %%
x = range(25)
y = [47.11,51.26,55.56,60.77,63.70,67.31,68.95,72.96,74.82,75.13,76.35,76.67,77.32,77.62,78.32,78.75,78.28,78.15,78.97,78.60,79.06,77.67,78.97,79.20,78.58]
plt.plot(x,y, linestyle='dashdot',color='blue',label='Train')
plt.xlabel('Number of iterations', fontsize=16)
plt.ylabel('Model Accuracy Percentile', fontsize=16)


q = [58.53,62.50,72.55,73.48,75.47,73.71,78.74,80.14,80.26,81.89,80.14,80.96,80.02,80.96,82.36,82.01,81.66,82.48,82.13,82.24,82.71,81.66,82.48,82.71,81.89] 
plt.plot(x,q, linestyle='dashdot',color='red',label='Test')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
pylab.savefig('Plots_Additional_Layer_Resnet18.png')
