# %%
import matplotlib.pyplot as plt
import pylab
from pylab import figure, axes, pie, title, show

# %%
x = range(25)
y = [80.94,86.39,87.89,88.59,86.92,88.32,89.56,89.92,92.11,93.34,93.67,93.87,94.17,94.20,94.52,94.92,94.53,95.29,95.19,95.07,95.12,95.14,95.07,94.85 ,94.92] 
plt.plot(x,y, linestyle='dashdot',color='blue',label='Train')
plt.xlabel('Number of iterations', fontsize=16)
plt.ylabel('Model Accuracy Percentile', fontsize=16)


q =[86.92,83.88,84.23,87.03,91.83,91.82,91.36,85.75,92.87,93.22,93.81,94.63,94.28,93.93,94.28,94.86,94.98,94.86,94.74,94.86,94.63,94.63,94.86,94.98,94.74] 
plt.plot(x,q, linestyle='dashdot',color='red',label='Test')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
pylab.savefig('Plots_ResNET-18(F = 2).png')
