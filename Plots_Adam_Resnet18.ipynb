# %%
import matplotlib.pyplot as plt
import pylab
from pylab import figure, axes, pie, title, show

# %%
x = range(25)
y = [85.25,89.78,89.64,90.99,91.84,92.31,92.46,94.26,95.03,95.36,95.23,95.51,95.61,96.10,95.87,96.61,96.21,96.65,96.55,96.37,96.46,96.55,96.57,96.28,96.68]
plt.plot(x,y, linestyle='dashdot',color='blue',label='Train')
plt.xlabel('Number of iterations', fontsize=16)
plt.ylabel('Model Accuracy Percentile', fontsize=16)


q = [91.12,89.14,92.41,88.32,92.52,92.06,89.95,94.63,94.74,94.86,95.09,95.56,94.74,95.44,95.09,95.21,95.44,95.44,95.33,95.68,95.33,95.56,95.56,95.44,95.44]
plt.plot(x,q, linestyle='dashdot',color='red',label='Test')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
pylab.savefig('Plots_Adam_Resnet18.png')
