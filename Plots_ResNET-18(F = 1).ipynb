# %%
import matplotlib.pyplot as plt
import pylab
from pylab import figure, axes, pie, title, show

# %%
x = range(25)
y = [82.44,86.60,87.27,87.83,88.28,89.09,89.92,91.98,93.33,92.85, 93.63,93.87,94.37,94.22,95.19,95.25,94.95,95.10,94.99,94.85,95.51,95.12,95.38,95.34,95.27] 
plt.plot(x,y, linestyle='dashdot',color='blue',label='Train')
plt.xlabel('Number of iterations', fontsize=16)
plt.ylabel('Model Accuracy Percentile', fontsize=16)


q = [88.20,88.08,89.37,87.73,87.03,85.51,87.03,92.64,93.46,93.81,94.16,93.69,94.51,94.63,94.74,94.51,94.28,94.74,94.51,94.63,94.98,94.98,94.63,94.63,94.74] 
plt.plot(x,q, linestyle='dashdot',color='red',label='Test')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
pylab.savefig('Plots_ResNET-18(F = 1).png')
